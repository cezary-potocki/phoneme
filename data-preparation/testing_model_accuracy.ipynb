# %%
import requests
import pyphi
import pandas as pd
from os import listdir
from os.path import isfile, join
import csv

target_dir = "/home/jupyter/notebooks/PoC/data-preparation/output/understanding_data/test_datasets/"

def predict(pair_left, pair_right):
    url = 'http://127.0.0.1:8009/predict?pair_left=' + pair_left + '&pair_right=' + pair_right
    headers = {"content-type": "application/json"}
    
    response = requests.get(url)
    if 'error' in response.text:
        #print('error in generating similarity for pairs: {pair_left}, {pair_right}'.format(pair_left=pair_left,pair_right=pair_right))
        return 0
    else:
        similarity = float(response.text)
        return similarity

def test_datasets(language_pair):
    path = target_dir + language_pair + '/'
    files = [f for f in listdir(path) if isfile(join(path, f))]
    for file in files:
        print('processing file')
        df = pd.read_csv(path + file,sep='\t', header=None)
        set_len = len(df)
        
        df['similarity'] = 0
        for index, row in df.iterrows():
            pair_left = row[1]
            pair_right = row[2]
            similarity = predict(pair_left,pair_right)
            df.loc[index, 'similarity'] = similarity
        df.to_csv(path + file,sep='\t', quoting=csv.QUOTE_NONE, mode = 'w', header=False, index=False)
        accuracy = 0
        if file.startswith('neg'):
            true_neg = df[df['similarity'] < 0.5]
            accuracy = len(true_neg) / len(df)
        elif file.startswith('pos'):
            true_pos = df[df['similarity'] > 0.5]
            accuracy = len(true_pos) / len(df)
        print('accuracy of file: {file} is {acc}'.format(file=file, acc=accuracy))

# %%
# %%time
test_datasets('eng_arb')

# %%
similarity = predict('احمد','أحمد')

# %%
similarity
# Out:
# 0.9752248767763376

# %%
# %%time
from multiprocessing.dummy import Pool as ThreadPool 
pool = ThreadPool(3) 
results = pool.map(test_datasets, ['eng_eng', 'eng_arb', 'arb_arb'])

# %%
df = pd.read_csv(target_dir + 'eng_arb/pos_eng_arb_4x4.tsv',sep='\t', header=None)

# %%
df
# Out:
#        0                             1                           2
# 0      1   MARAM NAOMI ANNABELLA ASALA  مرآم نَؤمي انّابيلّا أصاله
# 1      1   MARAM NAOMI ANNABELLA ASALA  مرآم نَؤمي انّابيلّا أصالة
# 2      1   MARAM NAOMI ANNABELLA ASALA    مرآم نَؤمي أنابيلا أصاله
# 3      1   MARAM NAOMI ANNABELLA ASALA    مرآم نَؤمي أنابيلا أصالة
# 4      1   MARAM NAOMI ANNABELLA ASALA   مرآم نَؤمي أنّابيله أصاله
# 5      1   MARAM NAOMI ANNABELLA ASALA   مرآم نَؤمي أنّابيله أصالة
# 6      1   MARAM NAOMI ANNABELLA ASALA  مرآم نعومي انّابيلّا أصاله
# 7      1   MARAM NAOMI ANNABELLA ASALA  مرآم نعومي انّابيلّا أصالة
# 8      1   MARAM NAOMI ANNABELLA ASALA    مرآم نعومي أنابيلا أصاله
# 9      1   MARAM NAOMI ANNABELLA ASALA    مرآم نعومي أنابيلا أصالة
# 10     1   MARAM NAOMI ANNABELLA ASALA   مرآم نعومي أنّابيله أصاله
# 11     1   MARAM NAOMI ANNABELLA ASALA   مرآم نعومي أنّابيله أصالة
# 12     1   MARAM NAOMI ANNABELLA ASALA  مرام نَؤمي انّابيلّا أصاله
# 13     1   MARAM NAOMI ANNABELLA ASALA  مرام نَؤمي انّابيلّا أصالة
# 14     1   MARAM NAOMI ANNABELLA ASALA    مرام نَؤمي أنابيلا أصاله
# 15     1   MARAM NAOMI ANNABELLA ASALA    مرام نَؤمي أنابيلا أصالة
# 16     1   MARAM NAOMI ANNABELLA ASALA   مرام نَؤمي أنّابيله أصاله
# 17     1   MARAM NAOMI ANNABELLA ASALA   مرام نَؤمي أنّابيله أصالة
# 18     1   MARAM NAOMI ANNABELLA ASALA  مرام نعومي انّابيلّا أصاله
# 19     1   MARAM NAOMI ANNABELLA ASALA  مرام نعومي انّابيلّا أصالة
# 20     1   MARAM NAOMI ANNABELLA ASALA    مرام نعومي أنابيلا أصاله
# 21     1   MARAM NAOMI ANNABELLA ASALA    مرام نعومي أنابيلا أصالة
# 22     1   MARAM NAOMI ANNABELLA ASALA   مرام نعومي أنّابيله أصاله
# 23     1   MARAM NAOMI ANNABELLA ASALA   مرام نعومي أنّابيله أصالة
# 24     1  MARAM NAOMI ANNABELLA ASALAH  مرآم نَؤمي انّابيلّا أصاله
# 25     1  MARAM NAOMI ANNABELLA ASALAH  مرآم نَؤمي انّابيلّا أصالة
# 26     1  MARAM NAOMI ANNABELLA ASALAH    مرآم نَؤمي أنابيلا أصاله
# 27     1  MARAM NAOMI ANNABELLA ASALAH    مرآم نَؤمي أنابيلا أصالة
# 28     1  MARAM NAOMI ANNABELLA ASALAH   مرآم نَؤمي أنّابيله أصاله
# 29     1  MARAM NAOMI ANNABELLA ASALAH   مرآم نَؤمي أنّابيله أصالة
# ...   ..                           ...                         ...
# 11281  1   TRINITY YASEEN MARIAH NAOMI      ترينيتي يس ماريه نَؤمي
# 11282  1   TRINITY YASEEN MARIAH NAOMI      ترينيتي يس ماريه نعومي
# 11283  1   TRINITY YASEEN MARIAH NAOMI      ترينيتي يس مارية نَؤمي
# 11284  1   TRINITY YASEEN MARIAH NAOMI      ترينيتي يس مارية نعومي
# 11285  1   TRINITY YASEEN MARIAH NAOMI      ترينيتي يس ماريا نَؤمي
# 11286  1   TRINITY YASEEN MARIAH NAOMI      ترينيتي يس ماريا نعومي
# 11287  1    TRINITY YASEEN MARIA NAOMI   ترينيتي ياسين ماريه نَؤمي
# 11288  1    TRINITY YASEEN MARIA NAOMI   ترينيتي ياسين ماريه نعومي
# 11289  1    TRINITY YASEEN MARIA NAOMI   ترينيتي ياسين مارية نَؤمي
# 11290  1    TRINITY YASEEN MARIA NAOMI   ترينيتي ياسين مارية نعومي
# 11291  1    TRINITY YASEEN MARIA NAOMI   ترينيتي ياسين ماريا نَؤمي
# 11292  1    TRINITY YASEEN MARIA NAOMI   ترينيتي ياسين ماريا نعومي
# 11293  1    TRINITY YASEEN MARIA NAOMI      ترينيتي يس ماريه نَؤمي
# 11294  1    TRINITY YASEEN MARIA NAOMI      ترينيتي يس ماريه نعومي
# 11295  1    TRINITY YASEEN MARIA NAOMI      ترينيتي يس مارية نَؤمي
# 11296  1    TRINITY YASEEN MARIA NAOMI      ترينيتي يس مارية نعومي
# 11297  1    TRINITY YASEEN MARIA NAOMI      ترينيتي يس ماريا نَؤمي
# 11298  1    TRINITY YASEEN MARIA NAOMI      ترينيتي يس ماريا نعومي
# 11299  1  TRINITY YASEEN MARIYAH NAOMI   ترينيتي ياسين ماريه نَؤمي
# 11300  1  TRINITY YASEEN MARIYAH NAOMI   ترينيتي ياسين ماريه نعومي
# 11301  1  TRINITY YASEEN MARIYAH NAOMI   ترينيتي ياسين مارية نَؤمي
# 11302  1  TRINITY YASEEN MARIYAH NAOMI   ترينيتي ياسين مارية نعومي
# 11303  1  TRINITY YASEEN MARIYAH NAOMI   ترينيتي ياسين ماريا نَؤمي
# 11304  1  TRINITY YASEEN MARIYAH NAOMI   ترينيتي ياسين ماريا نعومي
# 11305  1  TRINITY YASEEN MARIYAH NAOMI      ترينيتي يس ماريه نَؤمي
# 11306  1  TRINITY YASEEN MARIYAH NAOMI      ترينيتي يس ماريه نعومي
# 11307  1  TRINITY YASEEN MARIYAH NAOMI      ترينيتي يس مارية نَؤمي
# 11308  1  TRINITY YASEEN MARIYAH NAOMI      ترينيتي يس مارية نعومي
# 11309  1  TRINITY YASEEN MARIYAH NAOMI      ترينيتي يس ماريا نَؤمي
# 11310  1  TRINITY YASEEN MARIYAH NAOMI      ترينيتي يس ماريا نعومي
#
# [11311 rows x 3 columns]

# %%
# %%time
i = 0

df = df.sample(frac=1)
df = df.sample(frac=1)
df = df.sample(frac=0.07)
set_len = len(df)
df['similarity'] = 0
for index, row in df.iterrows():
    i += 1
    if i % 1000 == 0:
        print("processed {i} out of {t}".format(i=i, t=set_len))
    pair_left = row[1].lower()
    pair_right = row[2].lower()
    similarity = predict(pair_right, pair_left)
    df.loc[index, 'similarity'] = similarity
# Out:
# CPU times: user 1.77 s, sys: 140 ms, total: 1.91 s
# Wall time: 6.86 s

# %%
df['similarity'] = 0
for index, row in df.iterrows():
    pair_left = row[1].lower()
    pair_right = row[2].lower()
    similarity = predict( pair_right, pair_right)
    df.loc[index, 'similarity'] = similarity
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             try:  # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-194ec725d0f7> in <module>()
#       3     pair_left = row[1].lower()
#       4     pair_right = row[2].lower()
# ----> 5     similarity = predict( pair_right, pair_right)
#       6     df.loc[index, 'similarity'] = similarity
#
# <ipython-input-1-d2cdac1cc669> in predict(pair_left, pair_right)
#      12     headers = {"content-type": "application/json"}
#      13
# ---> 14     response = requests.get(url)
#      15     if 'error' in response.text:
#      16         #print('error in generating similarity for pairs: {pair_left}, {pair_right}'.format(pair_left=pair_left,pair_right=pair_right))
#
# /opt/anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /opt/anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /opt/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# /opt/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     637
#     638         # Send the request
# --> 639         r = adapter.send(request, **kwargs)
#     640
#     641         # Total elapsed time of the request (approximately)
#
# /opt/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     436                     decode_content=False,
#     437                     retries=self.max_retries,
# --> 438                     timeout=timeout
#     439                 )
#     440
#
# /opt/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /opt/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#     381                 try:
# --> 382                     httplib_response = conn.getresponse()
#     383                 except Exception as e:
#     384                     # Remove the TypeError from the exception chain in Python 3;
#
# /opt/anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /opt/anaconda3/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /opt/anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /opt/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
true_pos = df[df['similarity'] >= 0.5]
accuracy = len(true_pos) / len(df[df['similarity'] > 0])

# %%
accuracy
# Out:
# 0.9608585858585859

# %%
df[df['similarity'] < 0.5]
# Out:
#        0                         1                          2  similarity
# 9458   1   MICHAEL SOAD ISSAC EMMA   ميكائيل سُعاد إسحاق إيما    0.493831
# 9698   1   MIKHAEL SUAD ISSAC EMMA   ميخائيل سُعاد إسحاق إيما    0.493764
# 10050  1   MICHAIL SOAD ISAAK EMMA   ميخائيل سُعاد إسحاق إيما    0.493764
# 9650   1  MICHAEL SOAAD ISSAC EMMA   ميكائيل سُعاد إسحاق إيما    0.493831
# 9539   1  MICHAEL SUAAD ISAAK EMMA  ميخائيل سُعاد إسحاق ايمّا    0.484064
# 10129  1  MICHAIL SO'AD ISAAK EMMA  ميكائيل سُعاد إسحاق ايمّه    0.483813
# 9925   1  MIKHAEL SOAAD ISAAK EMMA  ميخائيل سُعاد اسحاق ايمّه    0.491376
# 10277  1  MICHAIL SOAAD ISSAC EMMA  ميخائيل سُعاد اسحاق ايمّه    0.491376
# 10599  1   MIKAEL SOAAD ISSAC EMMA  ميخائيل سُعاد اسحاق ايمّا    0.491411
# 9831   1  MIKHAEL SO'AD ISSAC EMMA  ميخائيل سُعاد اسحاق ايمّا    0.491411
# 9586   1  MICHAEL SUAAD ISSAC EMMA   ميكائيل سُعاد إسحاق إيما    0.493831
# 10485  1   MIKAEL SO'AD ISSAC EMMA  ميكائيل سُعاد اسحاق ايمّه    0.491733
# 9621   1  MICHAEL SOAAD ISAAK EMMA  ميكائيل سُعاد اسحاق ايمّه    0.491733
# 9443   1   MICHAEL SOAD ISSAC EMMA  ميخائيل سُعاد إسحاق ايمّا    0.484064
# 9441   1   MICHAEL SOAD ISSAC EMMA  ميخائيل سُعاد إسحاق ايمّه    0.483608
# 9479   1  MICHAEL SO'AD ISAAK EMMA  ميخائيل سُعاد اسحاق ايمّا    0.491411
# 10087  1   MICHAIL SOAD ISSAC EMMA  ميخائيل سُعاد اسحاق ايمّا    0.491411
# 10133  1  MICHAIL SO'AD ISAAK EMMA  ميكائيل سُعاد اسحاق ايمّه    0.491733
# 10130  1  MICHAIL SO'AD ISAAK EMMA   ميكائيل سُعاد إسحاق إيما    0.493831
# 10225  1  MICHAIL SUAAD ISSAC EMMA  ميكائيل سُعاد إسحاق ايمّه    0.483813
# 9431   1   MICHAEL SOAD ISAAK EMMA  ميكائيل سُعاد اسحاق ايمّا    0.491739
# 9799   1  MIKHAEL SO'AD ISAAK EMMA  ميخائيل سُعاد اسحاق ايمّا    0.491411
# 9409   1   MICHAEL SOAD ISAAK EMMA  ميخائيل سُعاد إسحاق ايمّه    0.483608
# 9442   1   MICHAEL SOAD ISSAC EMMA   ميخائيل سُعاد إسحاق إيما    0.493764
# 9907   1  MIKHAEL SUAAD ISSAC EMMA  ميكائيل سُعاد إسحاق ايمّا    0.484223
# 10487  1   MIKAEL SO'AD ISSAC EMMA  ميكائيل سُعاد اسحاق ايمّا    0.491739
# 9635   1  MICHAEL SOAAD ISSAC EMMA  ميخائيل سُعاد إسحاق ايمّا    0.484064
# 10002  1   MICHAIL SUAD ISAAK EMMA   ميكائيل سُعاد إسحاق إيما    0.493831

# %%
from multiprocessing.dummy import Pool as ThreadPool 
pool = ThreadPool(4) 
results = pool.map(my_function, my_array)
