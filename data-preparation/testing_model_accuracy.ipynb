# %%
import requests
import pyphi
import pandas as pd
from os import listdir
from os.path import isfile, join
import csv

target_dir = "/home/jupyter/notebooks/PoC/data-preparation/output/understanding_data/test_datasets/"

def predict(pair_left, pair_right):
    url = 'http://127.0.0.1:8009/predict?pair_left=' + pair_left + '&pair_right=' + pair_right
    headers = {"content-type": "application/json"}
    
    response = requests.get(url)
    if 'error' in response.text:
        #print('error in generating similarity for pairs: {pair_left}, {pair_right}'.format(pair_left=pair_left,pair_right=pair_right))
        return 0
    else:
        similarity = float(response.text)
        return similarity

def test_datasets(language_pair):
    path = target_dir + language_pair + '/'
    files = [f for f in listdir(path) if isfile(join(path, f))]
    for file in files:
        print('processing file')
        df = pd.read_csv(path + file,sep='\t', header=None)
        set_len = len(df)
        
        df['similarity'] = 0
        for index, row in df.iterrows():
            pair_left = row[1]
            pair_right = row[2]
            similarity = predict(pair_left,pair_right)
            df.loc[index, 'similarity'] = similarity
        df.to_csv(path + file,sep='\t', quoting=csv.QUOTE_NONE, mode = 'w', header=False, index=False)
        accuracy = 0
        if file.startswith('neg'):
            true_neg = df[df['similarity'] < 0.5]
            accuracy = len(true_neg) / len(df)
        elif file.startswith('pos'):
            true_pos = df[df['similarity'] > 0.5]
            accuracy = len(true_pos) / len(df)
        print('accuracy of file: {file} is {acc}'.format(file=file, acc=accuracy))

# %%
# %%time
test_datasets('eng_arb')

# %%
similarity = predict('احمد','أحمد')

# %%
similarity
# Out:
# 0.9752248767763376

# %%
# %%time
from multiprocessing.dummy import Pool as ThreadPool 
pool = ThreadPool(3) 
results = pool.map(test_datasets, ['eng_eng', 'eng_arb', 'arb_arb'])

# %%
df = pd.read_csv(target_dir + 'eng_arb/neg_eng_arb_4x4_unordered.tsv',sep='\t', header=None)

# %%
df
# Out:
#         0                             1                           2
# 0       0   MARAM NAOMI ANNABELLA ASALA  نَؤمي مرآم انّابيلّا أصاله
# 1       0   MARAM NAOMI ANNABELLA ASALA  نَؤمي مرآم انّابيلّا أصالة
# 2       0   MARAM NAOMI ANNABELLA ASALA    أصاله أنابيلا نَؤمي مرآم
# 3       0   MARAM NAOMI ANNABELLA ASALA    مرآم نَؤمي أصالة أنابيلا
# 4       0   MARAM NAOMI ANNABELLA ASALA   مرآم أنّابيله نَؤمي أصاله
# 5       0   MARAM NAOMI ANNABELLA ASALA   أنّابيله نَؤمي أصالة مرآم
# 6       0   MARAM NAOMI ANNABELLA ASALA  أصاله مرآم انّابيلّا نعومي
# 7       0   MARAM NAOMI ANNABELLA ASALA  نعومي مرآم أصالة انّابيلّا
# 8       0   MARAM NAOMI ANNABELLA ASALA    أنابيلا مرآم نعومي أصاله
# 9       0   MARAM NAOMI ANNABELLA ASALA    أنابيلا نعومي مرآم أصالة
# 10      0   MARAM NAOMI ANNABELLA ASALA   أصاله نعومي أنّابيله مرآم
# 11      0   MARAM NAOMI ANNABELLA ASALA   أنّابيله نعومي مرآم أصالة
# 12      0   MARAM NAOMI ANNABELLA ASALA  أصاله مرام انّابيلّا نَؤمي
# 13      0   MARAM NAOMI ANNABELLA ASALA  نَؤمي أصالة انّابيلّا مرام
# 14      0   MARAM NAOMI ANNABELLA ASALA    مرام أصاله أنابيلا نَؤمي
# 15      0   MARAM NAOMI ANNABELLA ASALA    أصالة أنابيلا مرام نَؤمي
# 16      0   MARAM NAOMI ANNABELLA ASALA   نَؤمي أنّابيله مرام أصاله
# 17      0   MARAM NAOMI ANNABELLA ASALA   مرام أنّابيله أصالة نَؤمي
# 18      0   MARAM NAOMI ANNABELLA ASALA  مرام انّابيلّا أصاله نعومي
# 19      0   MARAM NAOMI ANNABELLA ASALA  انّابيلّا نعومي مرام أصالة
# 20      0   MARAM NAOMI ANNABELLA ASALA    مرام أصاله أنابيلا نعومي
# 21      0   MARAM NAOMI ANNABELLA ASALA    أنابيلا مرام أصالة نعومي
# 22      0   MARAM NAOMI ANNABELLA ASALA   أنّابيله نعومي أصاله مرام
# 23      0   MARAM NAOMI ANNABELLA ASALA   أنّابيله نعومي مرام أصالة
# 24      0  MARAM NAOMI ANNABELLA ASALAH  نَؤمي أصاله انّابيلّا مرآم
# 25      0  MARAM NAOMI ANNABELLA ASALAH  نَؤمي انّابيلّا مرآم أصالة
# 26      0  MARAM NAOMI ANNABELLA ASALAH    نَؤمي مرآم أنابيلا أصاله
# 27      0  MARAM NAOMI ANNABELLA ASALAH    أنابيلا أصالة مرآم نَؤمي
# 28      0  MARAM NAOMI ANNABELLA ASALAH   أنّابيله نَؤمي مرآم أصاله
# 29      0  MARAM NAOMI ANNABELLA ASALAH   مرآم نَؤمي أصالة أنّابيله
# ...    ..                           ...                         ...
# 162240  0   TRINITY YASEEN MARIAH NAOMI      ترينيتي نَؤمي يس ماريه
# 162241  0   TRINITY YASEEN MARIAH NAOMI      نعومي ترينيتي ماريه يس
# 162242  0   TRINITY YASEEN MARIAH NAOMI      يس نَؤمي مارية ترينيتي
# 162243  0   TRINITY YASEEN MARIAH NAOMI      يس نعومي مارية ترينيتي
# 162244  0   TRINITY YASEEN MARIAH NAOMI      ماريا ترينيتي يس نَؤمي
# 162245  0   TRINITY YASEEN MARIAH NAOMI      ماريا يس نعومي ترينيتي
# 162246  0    TRINITY YASEEN MARIA NAOMI   ياسين ترينيتي نَؤمي ماريه
# 162247  0    TRINITY YASEEN MARIA NAOMI   نعومي ياسين ترينيتي ماريه
# 162248  0    TRINITY YASEEN MARIA NAOMI   ياسين ترينيتي نَؤمي مارية
# 162249  0    TRINITY YASEEN MARIA NAOMI   ياسين ترينيتي نعومي مارية
# 162250  0    TRINITY YASEEN MARIA NAOMI   ياسين ترينيتي نَؤمي ماريا
# 162251  0    TRINITY YASEEN MARIA NAOMI   نعومي ماريا ترينيتي ياسين
# 162252  0    TRINITY YASEEN MARIA NAOMI      ماريه ترينيتي يس نَؤمي
# 162253  0    TRINITY YASEEN MARIA NAOMI      ماريه يس نعومي ترينيتي
# 162254  0    TRINITY YASEEN MARIA NAOMI      ترينيتي يس نَؤمي مارية
# 162255  0    TRINITY YASEEN MARIA NAOMI      نعومي مارية يس ترينيتي
# 162256  0    TRINITY YASEEN MARIA NAOMI      يس ترينيتي ماريا نَؤمي
# 162257  0    TRINITY YASEEN MARIA NAOMI      ماريا ترينيتي يس نعومي
# 162258  0  TRINITY YASEEN MARIYAH NAOMI   نَؤمي ياسين ترينيتي ماريه
# 162259  0  TRINITY YASEEN MARIYAH NAOMI   ترينيتي ياسين نعومي ماريه
# 162260  0  TRINITY YASEEN MARIYAH NAOMI   ياسين نَؤمي ترينيتي مارية
# 162261  0  TRINITY YASEEN MARIYAH NAOMI   ياسين ترينيتي نعومي مارية
# 162262  0  TRINITY YASEEN MARIYAH NAOMI   ياسين ترينيتي ماريا نَؤمي
# 162263  0  TRINITY YASEEN MARIYAH NAOMI   ياسين نعومي ماريا ترينيتي
# 162264  0  TRINITY YASEEN MARIYAH NAOMI      ترينيتي نَؤمي ماريه يس
# 162265  0  TRINITY YASEEN MARIYAH NAOMI      نعومي يس ترينيتي ماريه
# 162266  0  TRINITY YASEEN MARIYAH NAOMI      نَؤمي مارية ترينيتي يس
# 162267  0  TRINITY YASEEN MARIYAH NAOMI      مارية يس نعومي ترينيتي
# 162268  0  TRINITY YASEEN MARIYAH NAOMI      يس ماريا ترينيتي نَؤمي
# 162269  0  TRINITY YASEEN MARIYAH NAOMI      يس نعومي ترينيتي ماريا
#
# [162270 rows x 3 columns]

# %%
# %%time
i = 0

df = df.sample(frac=1)
df = df.sample(frac=1)
df = df.sample(frac=0.07)
set_len = len(df)
df['similarity'] = 0
for index, row in df.iterrows():
    i += 1
    if i % 1000 == 0:
        print("processed {i} out of {t}".format(i=i, t=set_len))
    pair_left = row[1].lower()
    pair_right = row[2].lower()
    similarity = predict(pair_right, pair_left)
    df.loc[index, 'similarity'] = similarity
# Out:
# processed 1000 out of 11359
# processed 2000 out of 11359
# processed 3000 out of 11359
# processed 4000 out of 11359
# processed 5000 out of 11359
# processed 6000 out of 11359
# processed 7000 out of 11359
# processed 8000 out of 11359
# processed 9000 out of 11359
# processed 10000 out of 11359
# processed 11000 out of 11359
# CPU times: user 29.9 s, sys: 2.52 s, total: 32.4 s
# Wall time: 1min 57s

# %%
df['similarity'] = 0
for index, row in df.iterrows():
    pair_left = row[1].lower()
    pair_right = row[2].lower()
    similarity = predict( pair_right, pair_left)
    df.loc[index, 'similarity'] = similarity

# %%
true_pos = df[df['similarity'] >= 0.5]
accuracy = len(true_pos) / len(df[df['similarity'] > 0])

# %%
accuracy
# Out:
# 0.9482323232323232

# %%
df[df['similarity'] < 0.5]
# Out:
#        0                         1                          2  similarity
# 9458   1   MICHAEL SOAD ISSAC EMMA   ميكائيل سُعاد إسحاق إيما    0.493831
# 9698   1   MIKHAEL SUAD ISSAC EMMA   ميخائيل سُعاد إسحاق إيما    0.493764
# 10050  1   MICHAIL SOAD ISAAK EMMA   ميخائيل سُعاد إسحاق إيما    0.493764
# 9650   1  MICHAEL SOAAD ISSAC EMMA   ميكائيل سُعاد إسحاق إيما    0.493831
# 9539   1  MICHAEL SUAAD ISAAK EMMA  ميخائيل سُعاد إسحاق ايمّا    0.484064
# 10129  1  MICHAIL SO'AD ISAAK EMMA  ميكائيل سُعاد إسحاق ايمّه    0.483813
# 9925   1  MIKHAEL SOAAD ISAAK EMMA  ميخائيل سُعاد اسحاق ايمّه    0.491376
# 10277  1  MICHAIL SOAAD ISSAC EMMA  ميخائيل سُعاد اسحاق ايمّه    0.491376
# 10599  1   MIKAEL SOAAD ISSAC EMMA  ميخائيل سُعاد اسحاق ايمّا    0.491411
# 9831   1  MIKHAEL SO'AD ISSAC EMMA  ميخائيل سُعاد اسحاق ايمّا    0.491411
# 9586   1  MICHAEL SUAAD ISSAC EMMA   ميكائيل سُعاد إسحاق إيما    0.493831
# 10485  1   MIKAEL SO'AD ISSAC EMMA  ميكائيل سُعاد اسحاق ايمّه    0.491733
# 9621   1  MICHAEL SOAAD ISAAK EMMA  ميكائيل سُعاد اسحاق ايمّه    0.491733
# 9443   1   MICHAEL SOAD ISSAC EMMA  ميخائيل سُعاد إسحاق ايمّا    0.484064
# 9441   1   MICHAEL SOAD ISSAC EMMA  ميخائيل سُعاد إسحاق ايمّه    0.483608
# 9479   1  MICHAEL SO'AD ISAAK EMMA  ميخائيل سُعاد اسحاق ايمّا    0.491411
# 10087  1   MICHAIL SOAD ISSAC EMMA  ميخائيل سُعاد اسحاق ايمّا    0.491411
# 10133  1  MICHAIL SO'AD ISAAK EMMA  ميكائيل سُعاد اسحاق ايمّه    0.491733
# 10130  1  MICHAIL SO'AD ISAAK EMMA   ميكائيل سُعاد إسحاق إيما    0.493831
# 10225  1  MICHAIL SUAAD ISSAC EMMA  ميكائيل سُعاد إسحاق ايمّه    0.483813
# 9431   1   MICHAEL SOAD ISAAK EMMA  ميكائيل سُعاد اسحاق ايمّا    0.491739
# 9799   1  MIKHAEL SO'AD ISAAK EMMA  ميخائيل سُعاد اسحاق ايمّا    0.491411
# 9409   1   MICHAEL SOAD ISAAK EMMA  ميخائيل سُعاد إسحاق ايمّه    0.483608
# 9442   1   MICHAEL SOAD ISSAC EMMA   ميخائيل سُعاد إسحاق إيما    0.493764
# 9907   1  MIKHAEL SUAAD ISSAC EMMA  ميكائيل سُعاد إسحاق ايمّا    0.484223
# 10487  1   MIKAEL SO'AD ISSAC EMMA  ميكائيل سُعاد اسحاق ايمّا    0.491739
# 9635   1  MICHAEL SOAAD ISSAC EMMA  ميخائيل سُعاد إسحاق ايمّا    0.484064
# 10002  1   MICHAIL SUAD ISAAK EMMA   ميكائيل سُعاد إسحاق إيما    0.493831

# %%
from multiprocessing.dummy import Pool as ThreadPool 
pool = ThreadPool(4) 
results = pool.map(my_function, my_array)
